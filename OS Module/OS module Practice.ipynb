# %%
pwd
# Out:
# 'C:\\Users\\bbaja\\Desktop\\PythonProjects\\My Python Stuff\\My-Python-Stuff\\OS Module'

# %%
f = open('practice.txt','w+')
f.write('This is a test string')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\bbaja\\Desktop\\PythonProjects\\My Python Stuff\\My-Python-Stuff\\OS Module'

# %%
os.listdir('C:\\Users')
# Out:
# ['All Users', 'bbaja', 'Default', 'Default User', 'desktop.ini', 'Public']

# %%
import shutil

# %%
shutil.move('practice.txt','C:\\Users\\bbaja\\Desktop\\PythonProjects\\My Python Stuff\\My-Python-Stuff')
# Out:
# 'C:\\Users\\bbaja\\Desktop\\PythonProjects\\My Python Stuff\\My-Python-Stuff\\practice.txt'

# %%
os.listdir('C:\\Users\\bbaja\\Desktop\\PythonProjects\\My Python Stuff\\My-Python-Stuff')
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'About_pylint.ipynb',
#  'Collections Module',
#  'Decorators',
#  'Errors and Exception Handling.ipynb',
#  'Game On.ipynb',
#  'Generators',
#  'Main Milestone Project - 1.ipynb',
#  'Milestone - 2',
#  'Modules and Packages',
#  'myfirstnotebook.ipynb',
#  'MyMainPackage',
#  'myprogram.py',
#  'my_module',
#  'my_module.py',
#  'OOP Challenge Practice.ipynb',
#  'OOP.ipynb',
#  'OS Module',
#  'Practice 1.ipynb',
#  'Practice 2.ipynb',
#  'practice.txt',
#  'README.md',
#  'simple1.py',
#  'testfile',
#  'Unit Test Library',
#  '__pycache__']

# %%
#    os.remove() will delete a file.
#    os.rmdir() will delete an empty folder.
#    shutil.rmtree("nonempty-dir")

# Safer approach is send2trash
#import send2trash 
  
#send2trash.send2trash("/location/to/file")

# %%
file_path = 'C:\\Users\\bbaja\\Desktop\\PythonProjects\\My Python Stuff'
for folder , sub_folders, files in os.walk(file_path):
    print(f"Currently looking at {folder}")
    print('\n')
    print('The subfolders are:')
    for sub_fold in sub_folders:
            print(f"Subfolder: {sub_fold}")

    print('\n')
    print("the files are: ")
    for f in files:
        print(f"\n File: {f}")
    print('\n')
# Out:
# Currently looking at C:\Users\bbaja\Desktop\PythonProjects\My Python Stuff
#
#
# The subfolders are:
# Subfolder: .ipynb_checkpoints
# Subfolder: My-Python-Stuff
#
#
# the files are:
#
#  File: askdfjalsdkf.txt
#
#  File: my_file.txt
#
#  File: my_new_file.txt
#
#
# Currently looking at C:\Users\bbaja\Desktop\PythonProjects\My Python Stuff\.ipynb_checkpoints
#
#
# The subfolders are:
#
#
# the files are:
#
#  File: myfirstnotebook-checkpoint.ipynb
#
#  File: Tick Tac Toe-checkpoint.ipynb
#
#  File: Untitled-checkpoint.ipynb
#
#  File: Untitled1-checkpoint.ipynb
#
#
# Currently looking at C:\Users\bbaja\Desktop\PythonProjects\My Python Stuff\My-Python-Stuff
#
#
# The subfolders are:
# Subfolder: .git
# Subfolder: .ipynb_checkpoints
# Subfolder: Collections Module
# Subfolder: Decorators
# Subfolder: Generators
# Subfolder: Milestone - 2
# Subfolder: Modules and Packages
# Subfolder: MyMainPackage
# Subfolder: OS Module
# Subfolder: Unit Test Library
# Subfolder: __pycache__
#
#
# ...
