# %%
# Working with large images May need to increase the notebook rate limiter with

# %%
# jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10

# %%
from PIL import Image

# %%
mac = Image.open('example.jpg')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac.size
# Out:
# (220, 331)

# %%
mac.filename
# Out:
# 'example.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
# Cropping image

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
mac.size
# Out:
# (220, 331)

# %%
x = 0
y = 0
w = 220 / 4
h = 320 / 6

# %%
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=55x53>

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x331>

# %%
mac.size
# Out:
# (220, 331)
